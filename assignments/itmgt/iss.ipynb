# %%
import matplotlib.pyplot as plt
import time

timestamps = []
longitudes = []
latitudes = []

for record in range(100):
    
    data = []
    res = requests.get('http://api.open-notify.org/iss-now.json')
    json_data = res.json()
    
    # Data Points
    data.append(json_data['timestamp'])
    data.append(float(json_data['iss_position']['longitude']))
    data.append(float(json_data['iss_position']['latitude']))
    print(data)
    
    # Path of ISS
    timestamps.append(json_data['timestamp'])
    longitudes.append(float(json_data['iss_position']['longitude']))
    latitudes.append(float(json_data['iss_position']['latitude']))
    
    time.sleep(10)
# Out:
# [1689053546, -153.1776, 11.702]
# [1689053556, -152.7811, 12.2274]
# [1689053566, -152.4019, 12.727]
# [1689053577, -152.0019, 13.251]
# [1689053587, -151.6, 13.7742]
# [1689053598, -151.1961, 14.2966]
# [1689053608, -150.7899, 14.8183]
# [1689053618, -150.4013, 15.3142]
# [1689053629, -149.9909, 15.834]
# [1689053639, -149.5781, 16.3529]
# [1689053650, -149.163, 16.8709]
# [1689053660, -148.7453, 17.3878]
# [1689053671, -148.3249, 17.9036]
# [1689053684, -147.821, 18.5163]
# [1689053694, -147.3946, 19.0296]
# [1689053705, -146.9652, 19.5418]
# [1689053715, -146.5329, 20.0528]
# [1689053726, -146.0974, 20.5625]
# [1689053737, -145.6168, 21.1192]
# [1689053747, -145.1955, 21.6019]
# [1689053758, -144.7499, 22.1074]
# [1689053768, -144.3008, 22.6115]
# [1689053779, -143.8481, 23.1139]
# [1689053789, -143.4134, 23.5911]
# [1689053799, -142.9533, 24.0905]
# [1689053810, -142.4892, 24.5882]
# [1689053820, -142.0211, 25.0843]
# [1689053831, -141.5488, 25.5785]
# [1689053841, -141.0721, 26.0709]
# [1689053852, -140.5912, 26.5614]
# [1689053862, -140.1057, 27.05]
# [1689053873, -139.6155, 27.5367]
# [1689053883, -139.1206, 28.0212]
# [1689053893, -138.6447, 28.4808]
# [1689053908, -137.9224, 29.1664]
# [1689053918, -137.435, 29.6208]
# [1689053929, -136.9181, 30.0957]
# [1689053939, -136.3957, 30.5682]
# [1689053950, -135.8679, 31.0382]
# [1689053961, -135.3088, 31.5279]
# [1689053971, -134.7692, 31.9927]
# [1689053982, -134.2236, 32.4547]
# [1689053992, -133.6719, 32.914]
# [1689054002, -133.1407, 33.3488]
# [1689054014, -132.5497, 33.824]
# [1689054025, -131.9516, 34.2959]
# [1689054035, -131.374, 34.7432]
# [1689054045, -130.8175, 35.1662]
# [1689054056, -130.2266, 35.6071]
# [1689054066, -129.6286, 36.0447]
# [1689054077, -129.0235, 36.4787]
# [1689054087, -128.4111, 36.9093]
# [1689054097, -127.821, 37.3158]
# [1689054108, -127.194, 37.7391]
# [1689054118, -126.5593, 38.1585]
# [1689054129, -125.9166, 38.5741]
# [1689054140, -125.2037, 39.0245]
# [1689054150, -124.5759, 39.4121]
# [1689054161, -123.9087, 39.8148]
# [1689054172, -123.2008, 40.232]
# [1689054182, -122.5164, 40.6256]
# [1689054193, -121.8233, 41.0147]
# [1689054203, -121.1216, 41.3989]
# [1689054214, -120.4109, 41.7784]
# [1689054224, -119.6913, 42.1527]
# [1689054235, -118.9628, 42.5219]
# [1689054245, -118.2605, 42.8687]
# [1689054255, -117.514, 43.2276]
# [1689054266, -116.7581, 43.581]
# [1689054276, -115.9929, 43.9287]
# [1689054287, -115.2184, 44.2707]
# [1689054297, -114.4342, 44.6067]
# [1689054308, -113.6406, 44.9366]
# [1689054318, -112.8757, 45.2451]
# [1689054328, -112.0633, 45.5628]
# [1689054339, -111.2412, 45.8741]
# [1689054350, -110.3696, 46.193]
# [1689054363, -109.3259, 46.5603]
# [1689054374, -108.4312, 46.8628]
# [1689054385, -107.5673, 47.1443]
# [1689054395, -106.6938, 47.4186]
# [1689054406, -105.8109, 47.6854]
# [1689054417, -104.8758, 47.9569]
# [1689054428, -103.8873, 48.2316]
# [1689054439, -102.9752, 48.4742]
# [1689054449, -102.0981, 48.6978]
# [1689054459, -101.1685, 48.9247]
# [1689054470, -100.23, 49.1433]
# [1689054480, -99.2832, 49.3535]
# [1689054491, -98.328, 49.5551]
# [1689054501, -97.4107, 49.739]
# [1689054511, -96.4397, 49.9236]
# [1689054522, -95.4611, 50.0992]
# [1689054532, -94.4753, 50.2658]
# [1689054543, -93.4824, 50.4232]
# [1689054553, -92.4828, 50.5713]
# [1689054563, -91.5248, 50.7036]
# [1689054574, -90.4647, 50.8392]
# [1689054585, -89.4469, 50.9589]
# [1689054595, -88.4239, 51.0688]

# %%
plt.plot(longitudes, latitudes, '-o')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()
