# %% [markdown]
# # Importing Data

# %%
import pandas as pd

# Loading data
df = pd.read_csv('Passanger_booking_data.csv')
df.head(5)
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               1      Internet  RoundTrip             21              12
# 1               2      Internet  RoundTrip            262              19
# 2               1      Internet  RoundTrip            112              20
# 3               2      Internet  RoundTrip            243              22
# 4               1      Internet  RoundTrip             96              31
#
#    flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0            6        Tue  AKLHGH      Australia                    0
# 1            7        Sat  AKLDEL    New Zealand                    1
# 2            3        Sat  AKLDEL    New Zealand                    0
# 3           17        Wed  AKLDEL          India                    1
# 4            4        Sat  AKLDEL    New Zealand                    0
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# 0                     0                      0             7.21
# 1                     0                      0             5.52
# 2                     0                      0             5.52
# 3                     1                      0             5.52
# 4                     0                      1             5.52
#
#    booking_complete
# 0                 1
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %% [markdown]
# # Cleaning Data

# %%
print(df.shape)
# Out:
# (50002, 14)

# %%
# Removing null and duplicate data
print(f'{df.isna().sum().sum()} values are N/A')
print(f'{df.duplicated().sum().sum()} values are duplicated')
# Out:
# 0 values are N/A
# 719 values are duplicated

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (49283, 14)

# %%
print("Sales Channel")
print(df['sales_channel'].unique())
print("Trip Type")
print(df['trip_type'].unique())
# Out:
# Sales Channel
# ['Internet' 'Mobile']
# Trip Type
# ['RoundTrip' 'CircleTrip' 'OneWay']

# %%
# Adding new for booking destination (country), origin (airport), and destination (airport).
df['origin'] = df['route'].str[0:3]
df['destination'] = df['route'].str[3:6]

df.head(5)
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               1      Internet  RoundTrip             21              12
# 1               2      Internet  RoundTrip            262              19
# 2               1      Internet  RoundTrip            112              20
# 3               2      Internet  RoundTrip            243              22
# 4               1      Internet  RoundTrip             96              31
#
#    flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0            6        Tue  AKLHGH      Australia                    0
# 1            7        Sat  AKLDEL    New Zealand                    1
# 2            3        Sat  AKLDEL    New Zealand                    0
# 3           17        Wed  AKLDEL          India                    1
# 4            4        Sat  AKLDEL    New Zealand                    0
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# 0                     0                      0             7.21
# 1                     0                      0             5.52
# 2                     0                      0             5.52
# 3                     1                      0             5.52
# 4                     0                      1             5.52
#
#    booking_complete origin destination
# 0                 1    AKL         HGH
# 1                 0    AKL         DEL
# 2                 0    AKL         DEL
# 3                 0    AKL         DEL
# 4                 0    AKL         DEL

# %%
# Adding destination country with airports dataset from OpenFlights
airports = pd.read_csv('https://raw.githubusercontent.com/jpatokal/openflights/master/data/airports.dat', header=None)
airports.head(5)

#df = pd.merge(df,airports.iloc[:, 3],left_on='destination', right_on=airports.iloc[:, 4], how='left')

#df.columns.get_loc('destination')
#column_to_insert = df.pop(df.columns[16])
#df.insert(9, "booking_destination", column_to_insert)

#df.head(5)
#df.to_csv('updated_passengers.csv', index=False)
# Out:
#    0                                            1             2   \
# 0   1                               Goroka Airport        Goroka
# 1   2                               Madang Airport        Madang
# 2   3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3   4                               Nadzab Airport        Nadzab
# 4   5  Port Moresby Jacksons International Airport  Port Moresby
#
#                  3    4     5         6           7     8   9  10  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998  5282  10  U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001    20  10  U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005  5388  10  U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977   239  10  U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001   146  10  U
#
#                      11       12           13
# 0  Pacific/Port_Moresby  airport  OurAirports
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports

# %%
#df = pd.read_csv("updated_passengers.csv")
#df.head(5)
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               1      Internet  RoundTrip             21              12
# 1               2      Internet  RoundTrip            262              19
# 2               1      Internet  RoundTrip            112              20
# 3               2      Internet  RoundTrip            243              22
# 4               1      Internet  RoundTrip             96              31
#
#    flight_hour flight_day   route booking_origin booking_destination  \
# 0            6        Tue  AKLHGH      Australia               China
# 1            7        Sat  AKLDEL    New Zealand               India
# 2            3        Sat  AKLDEL    New Zealand               India
# 3           17        Wed  AKLDEL          India               India
# 4            4        Sat  AKLDEL    New Zealand               India
#
#    wants_extra_baggage  wants_preferred_seat  wants_in_flight_meals  \
# 0                    0                     0                      0
# 1                    1                     0                      0
# 2                    0                     0                      0
# 3                    1                     1                      0
# 4                    0                     0                      1
#
#    flight_duration  booking_complete origin destination
# 0             7.21                 1    AKL         HGH
# 1             5.52                 0    AKL         DEL
# 2             5.52                 0    AKL         DEL
# 3             5.52                 0    AKL         DEL
# 4             5.52                 0    AKL         DEL

# %%
# Fixing booking origin column (some are empty)

df[df['booking_origin'] == "(not set)"]
#df = pd.merge(df,airports.iloc[:, 3],left_on='destination', right_on=airports.iloc[:, 4], how='left')
# Out:
#        num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 254                 2      Internet  RoundTrip             14              17
# 1149                3      Internet  RoundTrip             40              17
# 4549                1      Internet  RoundTrip             29              38
# 6313                2      Internet  RoundTrip            197              42
# 6520                2      Internet  RoundTrip            248              24
# ...               ...           ...        ...            ...             ...
# 45923               2      Internet  RoundTrip             60               6
# 46009               1      Internet  RoundTrip            163               6
# 46045               1      Internet  RoundTrip              5               6
# 46849               1      Internet  RoundTrip             46               6
# 49432               1      Internet  RoundTrip             34               6
#
#        flight_hour flight_day   route booking_origin booking_destination  \
# 254             10        Sat  AKLKUL      (not set)            Malaysia
# 1149             0        Fri  AKLKUL      (not set)            Malaysia
# 4549            20        Wed  CKGTRZ      (not set)               India
# 6313             1        Thu  COKMEL      (not set)           Australia
# 6520            22        Fri  COKOOL      (not set)           Australia
# ...            ...        ...     ...            ...                 ...
# 45923           11        Mon  HGHHKT      (not set)            Thailand
# 46009            1        Mon  HGHSIN      (not set)           Singapore
# 46045           14        Fri  HGHTRZ      (not set)               India
# 46849           16        Wed  HNDPEN      (not set)            Malaysia
# 49432            1        Thu  PEKPEN      (not set)            Malaysia
#
#        wants_extra_baggage  wants_preferred_seat  wants_in_flight_meals  \
# 254                      1                     0                      0
# 1149                     0                     0                      0
# 4549                     1                     0                      1
# 6313                     1                     1                      1
# 6520                     1                     0                      0
# ...                    ...                   ...                    ...
# 45923                    1                     0                      0
# 46009                    0                     0                      0
# 46045                    1                     1                      0
# 46849                    1                     0                      0
# 49432                    0                     0                      0
#
#        flight_duration  booking_complete origin destination
# 254               8.83                 1    AKL         KUL
# 1149              8.83                 0    AKL         KUL
# 4549              4.83                 0    CKG         TRZ
# 6313              8.83                 0    COK         MEL
# 6520              8.83                 0    COK         OOL
# ...                ...               ...    ...         ...
# 45923             5.07                 0    HGH         HKT
# 46009             5.07                 0    HGH         SIN
# 46045             5.07                 1    HGH         TRZ
# 46849             7.57                 1    HND         PEN
# 49432             6.42                 0    PEK         PEN
#
# [84 rows x 17 columns]

# %%
df = pd.read_csv("updated_passengers.csv")
#df = df.drop(columns=['booking_origin'])
df.head(5)
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               1      Internet  RoundTrip             21              12
# 1               2      Internet  RoundTrip            262              19
# 2               1      Internet  RoundTrip            112              20
# 3               2      Internet  RoundTrip            243              22
# 4               1      Internet  RoundTrip             96              31
#
#    flight_hour flight_day   route booking_destination  wants_extra_baggage  \
# 0            6        Tue  AKLHGH               China                    0
# 1            7        Sat  AKLDEL               India                    1
# 2            3        Sat  AKLDEL               India                    0
# 3           17        Wed  AKLDEL               India                    1
# 4            4        Sat  AKLDEL               India                    0
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# 0                     0                      0             7.21
# 1                     0                      0             5.52
# 2                     0                      0             5.52
# 3                     1                      0             5.52
# 4                     0                      1             5.52
#
#    booking_complete origin destination
# 0                 1    AKL         HGH
# 1                 0    AKL         DEL
# 2                 0    AKL         DEL
# 3                 0    AKL         DEL
# 4                 0    AKL         DEL

# %%
df = pd.merge(df,airports.iloc[:, 3],left_on='origin', right_on=airports.iloc[:, 4], how='left')

#df.columns.get_loc('destination')

column_to_insert = df.pop(df.columns[16])
df.insert(8, "booking_origin", column_to_insert)

df.head(5)
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               1      Internet  RoundTrip             21              12
# 1               2      Internet  RoundTrip            262              19
# 2               1      Internet  RoundTrip            112              20
# 3               2      Internet  RoundTrip            243              22
# 4               1      Internet  RoundTrip             96              31
#
#    flight_hour flight_day   route booking_origin booking_destination  \
# 0            6        Tue  AKLHGH    New Zealand               China
# 1            7        Sat  AKLDEL    New Zealand               India
# 2            3        Sat  AKLDEL    New Zealand               India
# 3           17        Wed  AKLDEL    New Zealand               India
# 4            4        Sat  AKLDEL    New Zealand               India
#
#    wants_extra_baggage  wants_preferred_seat  wants_in_flight_meals  \
# 0                    0                     0                      0
# 1                    1                     0                      0
# 2                    0                     0                      0
# 3                    1                     1                      0
# 4                    0                     0                      1
#
#    flight_duration  booking_complete origin destination
# 0             7.21                 1    AKL         HGH
# 1             5.52                 0    AKL         DEL
# 2             5.52                 0    AKL         DEL
# 3             5.52                 0    AKL         DEL
# 4             5.52                 0    AKL         DEL

# %%
df.to_csv('updated_passengers.csv', index=False)
# Out:
# (49283, 14)

# %%
df['booking_destination'].value_counts()
# Out:
# Australia       18848
# Malaysia         7025
# Taiwan           4044
# China            3779
# Japan            3545
# South Korea      3252
# Singapore        2157
# Vietnam          1696
# Indonesia        1002
# India             889
# Cambodia          882
# Thailand          714
# Nepal             588
# Philippines       338
# Macau             306
# Burma             292
# Maldives          227
# Mauritius         187
# Iran              142
# Laos               51
# Hong Kong          23
# Saudi Arabia       15
# Name: booking_destination, dtype: int64

# %%
df[df['booking_origin'] == "(not set)"]
# Out:
# Empty DataFrame
# Columns: [num_passengers, sales_channel, trip_type, purchase_lead, length_of_stay, flight_hour, flight_day, route, booking_origin, booking_destination, wants_extra_baggage, wants_preferred_seat, wants_in_flight_meals, flight_duration, booking_complete, origin, destination]
# Index: []

# %%
df.head(5)
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               1      Internet  RoundTrip             21              12
# 1               2      Internet  RoundTrip            262              19
# 2               1      Internet  RoundTrip            112              20
# 3               2      Internet  RoundTrip            243              22
# 4               1      Internet  RoundTrip             96              31
#
#    flight_hour flight_day   route booking_origin booking_destination  \
# 0            6        Tue  AKLHGH    New Zealand               China
# 1            7        Sat  AKLDEL    New Zealand               India
# 2            3        Sat  AKLDEL    New Zealand               India
# 3           17        Wed  AKLDEL    New Zealand               India
# 4            4        Sat  AKLDEL    New Zealand               India
#
#    wants_extra_baggage  wants_preferred_seat  wants_in_flight_meals  \
# 0                    0                     0                      0
# 1                    1                     0                      0
# 2                    0                     0                      0
# 3                    1                     1                      0
# 4                    0                     0                      1
#
#    flight_duration  booking_complete origin destination
# 0             7.21                 1    AKL         HGH
# 1             5.52                 0    AKL         DEL
# 2             5.52                 0    AKL         DEL
# 3             5.52                 0    AKL         DEL
# 4             5.52                 0    AKL         DEL

# %%
df['country_route'] = df['booking_origin'] + ' to ' + df['booking_destination']
df.head(5)
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               1      Internet  RoundTrip             21              12
# 1               2      Internet  RoundTrip            262              19
# 2               1      Internet  RoundTrip            112              20
# 3               2      Internet  RoundTrip            243              22
# 4               1      Internet  RoundTrip             96              31
#
#    flight_hour flight_day   route booking_origin booking_destination  \
# 0            6        Tue  AKLHGH    New Zealand               China
# 1            7        Sat  AKLDEL    New Zealand               India
# 2            3        Sat  AKLDEL    New Zealand               India
# 3           17        Wed  AKLDEL    New Zealand               India
# 4            4        Sat  AKLDEL    New Zealand               India
#
#    wants_extra_baggage  wants_preferred_seat  wants_in_flight_meals  \
# 0                    0                     0                      0
# 1                    1                     0                      0
# 2                    0                     0                      0
# 3                    1                     1                      0
# 4                    0                     0                      1
#
#    flight_duration  booking_complete origin destination         country_route
# 0             7.21                 1    AKL         HGH  New Zealand to China
# 1             5.52                 0    AKL         DEL  New Zealand to India
# 2             5.52                 0    AKL         DEL  New Zealand to India
# 3             5.52                 0    AKL         DEL  New Zealand to India
# 4             5.52                 0    AKL         DEL  New Zealand to India

# %%
#df.to_csv('updated_passengers.csv', index=False)

# %%
df = pd.read_csv("updated_passengers.csv")
#df.head(5)

df = df.drop_duplicates()
#df.shape
df.to_csv('updated_passengers.csv', index=False)

# %%
booked = df[df['booking_complete'] == 1]
booked.head(5)
#booked.to_csv('booked_passengers.csv', index=False)
# Out:
#      num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0                 1      Internet  RoundTrip             21              12
# 84                1      Internet  RoundTrip             15              31
# 88                1      Internet  RoundTrip            156              19
# 96                1      Internet  RoundTrip            181              87
# 111               1        Mobile  RoundTrip            127              17
#
#      flight_hour flight_day   route booking_origin booking_destination  \
# 0              6        Tue  AKLHGH    New Zealand               China
# 84            17        Mon  AKLKUL    New Zealand            Malaysia
# 88            14        Mon  AKLKUL    New Zealand            Malaysia
# 96             2        Tue  AKLKUL    New Zealand            Malaysia
# 111           16        Tue  AKLKUL    New Zealand            Malaysia
#
#      wants_extra_baggage  wants_preferred_seat  wants_in_flight_meals  \
# 0                      0                     0                      0
# 84                     0                     0                      0
# 88                     1                     0                      0
# 96                     1                     0                      1
# 111                    1                     0                      1
#
#      flight_duration  booking_complete origin destination  \
# 0               7.21                 1    AKL         HGH
# 84              8.83                 1    AKL         KUL
# 88              8.83                 1    AKL         KUL
# 96              8.83                 1    AKL         KUL
# 111             8.83                 1    AKL         KUL
#
#                country_route
# 0       New Zealand to China
# 84   New Zealand to Malaysia
# 88   New Zealand to Malaysia
# 96   New Zealand to Malaysia
# 111  New Zealand to Malaysia

# %%
not_booked = df[df['booking_complete'] == 0]
not_booked.head(5)
#booked.to_csv('not_booked_passengers.csv', index=False)
